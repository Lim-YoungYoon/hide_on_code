# %% [markdown]
# ## **Fashion-MNIST 분류 및 전이학습 가이드**
#
# ### **1. 목표**
#
# - Fashion-MNIST 데이터셋을 분류하는 신경망 모델을 작성합니다.
# - 사전학습된 모델(MobileNetV2)을 사용하여 전이학습과 파인튜닝을 진행합니다.
# - 데이터 증강(Data Augmentation)을 적용하여 학습 데이터를 늘립니다.
# - 모델 성능을 높이기 위한 기법 5가지를 실습에 포함합니다.
# - K-Fold Cross Validation과 앙상블 기법을 활용하여 성능을 더욱 향상시킵니다.
#
# ---
#
# ### **2. 실습 단계**
#
# ### **Step 1: 데이터 로드 및 전처리**
#
# 1. `tensorflow.keras.datasets`에서 `fashion_mnist` 데이터를 로드합니다.
# 2. 데이터를 0~1 범위로 정규화하고, 채널 차원을 추가합니다.
# 3. 입력 이미지를 MobileNetV2 모델과 호환되도록 96x96 크기로 업샘플링합니다.
#
# ### **Step 2: 데이터 증강(Data Augmentation)**
#
# 1. `ImageDataGenerator`를 사용하여 데이터 증강을 설정합니다.
#     - 회전: `rotation_range=20`
#     - 이동: `width_shift_range=0.2`, `height_shift_range=0.2`
#     - 플립: `horizontal_flip=True`
# 2. 증강된 데이터를 학습에 활용하도록 준비합니다.
#
# ### **Step 3: 사전학습 모델 준비 (Transfer Learning)**
#
# 1. MobileNetV2 모델을 `tensorflow.keras.applications`에서 로드합니다.
#     - `weights='imagenet'`, `include_top=False`, `input_shape=(96, 96, 3)`
# 2. `base_model.trainable=False`로 설정하여 초기에는 사전학습된 가중치를 고정합니다.
#
# ### **Step 4: 모델 구성**
#
# 1. 사전학습 모델 위에 새로운 층을 추가합니다:
#     - Global Average Pooling 층.
#     - Fully Connected Dense 층 (128 units, ReLU 활성화, L2 정규화 적용).
#     - Dropout 층 (20%).
#     - Batch Normalization 층.
#     - 출력 층 (10개의 클래스, Softmax 활성화).
#
# ### **Step 5: 모델 컴파일 및 학습**
#
# 1. Adam 옵티마이저를 사용하여 모델을 컴파일합니다.
# 2. Early Stopping을 설정하여 검증 성능이 더 이상 개선되지 않을 때 학습을 중단합니다.
# 3. 증강된 데이터를 사용해 모델을 학습시킵니다.
#
# ### **Step 6: 파인튜닝 (Fine-Tuning)**
#
# 1. `base_model.trainable=True`로 변경하여 사전학습된 모델의 일부 층을 학습 가능하도록 설정합니다.
# 2. 낮은 학습률(예: 0.0001)로 모델을 다시 컴파일하고 추가 학습을 진행합니다.
#
# ### **Step 7: K-Fold Cross Validation**
#
# 1. 데이터를 K개의 폴드로 나누어 교차 검증을 수행합니다.
# 2. 각 폴드에서 모델을 학습시키고 성능을 평가한 뒤 평균 성능을 계산합니다.
# 3. K-Fold를 적용해 학습 데이터의 활용도를 극대화합니다.
#
#
# ### **Step 8: 앙상블 기법 적용**
#
# 1. 서로 다른 구조의 모델을 학습시킨 후 결과를 결합하여 최종 성능을 향상시킵니다.
#
# ### **앙상블 방법**
#
# - **소프트보팅(Soft Voting)**: 각 모델의 확률 출력 값을 평균하여 최종 결과 결정.
# - **하드보팅(Hard Voting)**: 각 모델의 예측 클래스 중 다수결로 최종 결과 결정.
# - **가중치 앙상블(Weighted Ensemble)**: 성능 비율에 따라 각 모델의 기여도를 조정.
# - **스태킹(Stacking)**: 각 모델의 출력을 메타 모델(Random Forest, XGBoost 등)에 입력으로 사용하여 최종 결과 예측.
#
#
# ### **Step 9: 모델 평가**
#
# 1. 테스트 데이터를 사용하여 앙상블된 모델 성능을 평가합니다.
# 2. 최종 정확도(Accuracy)를 확인합니다.
#
# ---
#
# ### **3. 성능을 높이기 위한 기법 적용**
#
# 1. **Dropout**: 과적합 방지를 위해 뉴런 일부를 비활성화.
# 2. **L2 정규화**: 손실 함수에 가중치 패널티를 추가해 안정화.
# 3. **Batch Normalization**: 각 층의 입력을 정규화하여 학습 안정화 및 속도 향상.
# 4. **Early Stopping**: 검증 성능이 개선되지 않으면 학습 조기 종료.
# 5. **데이터 증강**: 회전, 이동, 플립 등으로 데이터를 다양화.
# 6. **K-Fold Cross Validation**: 데이터를 효율적으로 활용하여 성능 평가 안정화.
# 7. **앙상블 기법**: 여러 모델의 결과를 결합하여 성능 향상.

# %% [markdown]
# # Step 1: 데이터 로드 및 전처리

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# 이미지 크기 설정
IMG_HEIGHT = 96
IMG_WIDTH = 96
IMG_CHANNELS = 3

# Fashion-MNIST 데이터셋 로드
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# OOM 방지를 위해 데이터 일부만 사용
x_train = x_train[:10000]
y_train = y_train[:10000]

# 데이터 정규화 및 차원 확장
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train = x_train[..., tf.newaxis]
x_test = x_test[..., tf.newaxis]

# MobileNetV2 입력 크기로 변경 및 채널 확장
x_train = tf.image.resize(x_train, (IMG_HEIGHT, IMG_WIDTH))
x_test = tf.image.resize(x_test, (IMG_HEIGHT, IMG_WIDTH))

x_train = tf.image.grayscale_to_rgb(x_train)
x_test = tf.image.grayscale_to_rgb(x_test)

# %% [markdown]
# # Step 2: 데이터 증강 (Data Augmentation)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)
datagen.fit(x_train)

# %% [markdown]
# # Step 3: 사전학습 모델 준비 (Transfer Learning)

# %%
from tensorflow.keras import layers, models, applications
from tensorflow.keras.regularizers import l2

def create_model():
    base_model = applications.MobileNetV2(
        input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS),
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = False  # Feature Extraction 단계에서는 동결

    model = models.Sequential([
        layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(64, activation='relu', kernel_regularizer=l2(0.01)),  # L2 정규화 적용
        layers.Dropout(0.2),  # Dropout 적용
        layers.BatchNormalization(),  # 배치 정규화 적용
        layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# # Step 4: K-Fold Cross Validation 적용

# %%
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping

kf = KFold(n_splits=5, shuffle=True, random_state=42)
models_list = []

for fold, (train_index, val_index) in enumerate(kf.split(x_train)):
    print(f"Training on Fold {fold+1}")
    x_train_fold, x_val_fold = x_train.numpy()[train_index], x_train.numpy()[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    model = create_model()

    # Early Stopping 적용
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    base_epochs = 15
    model.fit(
        datagen.flow(x_train_fold, y_train_fold, batch_size=128),
        validation_data=(x_val_fold, y_val_fold),
        epochs=base_epochs,
        callbacks=[early_stopping]
    )

    models_list.append(model)
# Out:
# Training on Fold 1
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 482ms/step - accuracy: 0.5365 - loss: 2.4775 - val_accuracy: 0.7935 - val_loss: 1.2775
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 264ms/step - accuracy: 0.7867 - loss: 1.2643 - val_accuracy: 0.8285 - val_loss: 0.9441
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 264ms/step - accuracy: 0.8108 - loss: 0.9588 - val_accuracy: 0.8255 - val_loss: 0.8122
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8341 - loss: 0.7853 - val_accuracy: 0.8235 - val_loss: 0.7293
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8230 - loss: 0.7404 - val_accuracy: 0.8475 - val_loss: 0.6181
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 269ms/step - accuracy: 0.8328 - loss: 0.6621 - val_accuracy: 0.8345 - val_loss: 0.6122
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 270ms/step - accuracy: 0.8350 - loss: 0.6220 - val_accuracy: 0.8415 - val_loss: 0.5660
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8381 - loss: 0.6036 - val_accuracy: 0.8295 - val_loss: 0.5738
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8309 - loss: 0.5974 - val_accuracy: 0.8430 - val_loss: 0.5353
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 263ms/step - accuracy: 0.8372 - loss: 0.5848 - val_accuracy: 0.8215 - val_loss: 0.5951
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 264ms/step - accuracy: 0.8340 - loss: 0.5810 - val_accuracy: 0.8360 - val_loss: 0.5826
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 268ms/step - accuracy: 0.8318 - loss: 0.5850 - val_accuracy: 0.8285 - val_loss: 0.5607
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 268ms/step - accuracy: 0.8320 - loss: 0.5794 - val_accuracy: 0.8385 - val_loss: 0.5743
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8449 - loss: 0.5711 - val_accuracy: 0.8290 - val_loss: 0.5596
# Training on Fold 2
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 373ms/step - accuracy: 0.5242 - loss: 2.5100 - val_accuracy: 0.8040 - val_loss: 1.2555
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.7832 - loss: 1.2307 - val_accuracy: 0.8445 - val_loss: 0.9057
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 269ms/step - accuracy: 0.7974 - loss: 0.9703 - val_accuracy: 0.7810 - val_loss: 0.9400
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8135 - loss: 0.8117 - val_accuracy: 0.8500 - val_loss: 0.6925
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.8217 - loss: 0.7274 - val_accuracy: 0.8340 - val_loss: 0.6594
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8267 - loss: 0.6736 - val_accuracy: 0.8425 - val_loss: 0.6156
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 268ms/step - accuracy: 0.8243 - loss: 0.6460 - val_accuracy: 0.8275 - val_loss: 0.6044
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.8328 - loss: 0.6104 - val_accuracy: 0.8520 - val_loss: 0.5457
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 269ms/step - accuracy: 0.8289 - loss: 0.6061 - val_accuracy: 0.8605 - val_loss: 0.5441
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8428 - loss: 0.5772 - val_accuracy: 0.8470 - val_loss: 0.5605
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 264ms/step - accuracy: 0.8442 - loss: 0.5678 - val_accuracy: 0.8550 - val_loss: 0.5489
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8325 - loss: 0.5720 - val_accuracy: 0.8390 - val_loss: 0.5518
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8433 - loss: 0.5614 - val_accuracy: 0.8570 - val_loss: 0.5169
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 271ms/step - accuracy: 0.8406 - loss: 0.5491 - val_accuracy: 0.8240 - val_loss: 0.7467
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 263ms/step - accuracy: 0.8291 - loss: 0.5688 - val_accuracy: 0.8335 - val_loss: 0.5504
# Training on Fold 3
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 373ms/step - accuracy: 0.5344 - loss: 2.5208 - val_accuracy: 0.8060 - val_loss: 1.2873
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.7988 - loss: 1.2394 - val_accuracy: 0.8210 - val_loss: 0.9621
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 270ms/step - accuracy: 0.7991 - loss: 0.9758 - val_accuracy: 0.8425 - val_loss: 0.8021
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 269ms/step - accuracy: 0.8170 - loss: 0.8103 - val_accuracy: 0.8320 - val_loss: 0.7422
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 268ms/step - accuracy: 0.8259 - loss: 0.7071 - val_accuracy: 0.8380 - val_loss: 0.6598
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.8274 - loss: 0.6746 - val_accuracy: 0.8375 - val_loss: 0.6278
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 271ms/step - accuracy: 0.8293 - loss: 0.6346 - val_accuracy: 0.8335 - val_loss: 0.5944
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8382 - loss: 0.6139 - val_accuracy: 0.8440 - val_loss: 0.5941
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 264ms/step - accuracy: 0.8366 - loss: 0.5845 - val_accuracy: 0.8145 - val_loss: 0.6232
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8426 - loss: 0.5685 - val_accuracy: 0.8345 - val_loss: 0.5878
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8355 - loss: 0.5836 - val_accuracy: 0.8310 - val_loss: 0.5863
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8440 - loss: 0.5518 - val_accuracy: 0.8155 - val_loss: 0.6195
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8419 - loss: 0.5628 - val_accuracy: 0.8460 - val_loss: 0.5540
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 264ms/step - accuracy: 0.8364 - loss: 0.5477 - val_accuracy: 0.8280 - val_loss: 0.5817
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 269ms/step - accuracy: 0.8359 - loss: 0.5591 - val_accuracy: 0.8225 - val_loss: 0.6117
# Training on Fold 4
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 372ms/step - accuracy: 0.5426 - loss: 2.4741 - val_accuracy: 0.7760 - val_loss: 1.3422
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 269ms/step - accuracy: 0.7832 - loss: 1.2504 - val_accuracy: 0.8340 - val_loss: 0.9482
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8274 - loss: 0.9095 - val_accuracy: 0.8235 - val_loss: 0.8261
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.8277 - loss: 0.8046 - val_accuracy: 0.8300 - val_loss: 0.7192
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8254 - loss: 0.7174 - val_accuracy: 0.8395 - val_loss: 0.6616
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8336 - loss: 0.6652 - val_accuracy: 0.8310 - val_loss: 0.6388
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 271ms/step - accuracy: 0.8340 - loss: 0.6300 - val_accuracy: 0.8425 - val_loss: 0.5938
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8438 - loss: 0.5975 - val_accuracy: 0.8475 - val_loss: 0.5746
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8310 - loss: 0.5875 - val_accuracy: 0.8440 - val_loss: 0.5623
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8412 - loss: 0.5727 - val_accuracy: 0.8265 - val_loss: 0.6109
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8326 - loss: 0.5817 - val_accuracy: 0.8455 - val_loss: 0.5713
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.8366 - loss: 0.5635 - val_accuracy: 0.8460 - val_loss: 0.5395
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8349 - loss: 0.5659 - val_accuracy: 0.8400 - val_loss: 0.5702
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8380 - loss: 0.5449 - val_accuracy: 0.8430 - val_loss: 0.5509
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 268ms/step - accuracy: 0.8450 - loss: 0.5490 - val_accuracy: 0.8445 - val_loss: 0.5575
# Training on Fold 5
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 375ms/step - accuracy: 0.5620 - loss: 2.4181 - val_accuracy: 0.7910 - val_loss: 1.3210
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.7886 - loss: 1.2564 - val_accuracy: 0.8205 - val_loss: 0.9756
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 269ms/step - accuracy: 0.8246 - loss: 0.9225 - val_accuracy: 0.8360 - val_loss: 0.7971
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.8176 - loss: 0.8121 - val_accuracy: 0.8470 - val_loss: 0.6826
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8239 - loss: 0.7310 - val_accuracy: 0.8400 - val_loss: 0.6444
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.8313 - loss: 0.6723 - val_accuracy: 0.8375 - val_loss: 0.6497
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8253 - loss: 0.6514 - val_accuracy: 0.8360 - val_loss: 0.5967
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 264ms/step - accuracy: 0.8407 - loss: 0.6040 - val_accuracy: 0.8385 - val_loss: 0.6194
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 267ms/step - accuracy: 0.8342 - loss: 0.6076 - val_accuracy: 0.8210 - val_loss: 0.6136
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 265ms/step - accuracy: 0.8366 - loss: 0.5788 - val_accuracy: 0.8385 - val_loss: 0.5736
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8327 - loss: 0.5799 - val_accuracy: 0.8305 - val_loss: 0.5915
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8366 - loss: 0.5616 - val_accuracy: 0.8285 - val_loss: 0.5836
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 268ms/step - accuracy: 0.8339 - loss: 0.5692 - val_accuracy: 0.8455 - val_loss: 0.5575
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 269ms/step - accuracy: 0.8359 - loss: 0.5697 - val_accuracy: 0.8375 - val_loss: 0.5663
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.8332 - loss: 0.5621 - val_accuracy: 0.8295 - val_loss: 0.5915

# %% [markdown]
# # Step 5: 앙상블 기법 적용

# %%
from scipy.stats import mode

# 모델별 예측값 저장
predictions = np.array([model.predict(x_test) for model in models_list])

# 5-1. 소프트보팅 (Soft Voting)
final_pred_soft = np.mean(predictions, axis=0)
final_classes_soft = np.argmax(final_pred_soft, axis=1)

# 5-2. 하드보팅 (Hard Voting)
final_classes_hard = mode([np.argmax(pred, axis=1) for pred in predictions], axis=0)[0].flatten()

# 5-3. 가중치 앙상블 (Weighted Ensemble)
weights = [0.3, 0.1, 0.2, 0.2, 0.2]  # 첫 번째 모델에 높은 가중치 부여
final_pred_weighted = sum(weights[i] * predictions[i] for i in range(len(models_list)))
final_classes_weighted = np.argmax(final_pred_weighted, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %% [markdown]
# # Step 6: 모델 평가

# %%
test_acc_soft = np.mean(final_classes_soft == y_test)
test_acc_hard = np.mean(final_classes_hard == y_test)
test_acc_weighted = np.mean(final_classes_weighted == y_test)

print(f"Soft Voting Accuracy: {test_acc_soft:.4f}")
print(f"Hard Voting Accuracy: {test_acc_hard:.4f}")
print(f"Weighted Ensemble Accuracy: {test_acc_weighted:.4f}")
# Out:
# Soft Voting Accuracy: 0.8554
# Hard Voting Accuracy: 0.8549
# Weighted Ensemble Accuracy: 0.8561

# %% [markdown]
# # Step 7: 미세 조정 (Fine-Tuning)

# %%
# 일부 레이어를 학습 가능하게 변경
fine_tune_at = 100  # 특정 레이어부터 학습 가능하게 조정
fine_tune_epochs = 15
total_epochs = 15 + fine_tune_epochs

for model in models_list:
    base_model = model.layers[0]  # MobileNetV2 모델 가져오기
    base_model.trainable = True

    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    # Fine-tuning을 위한 학습률 조정
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

# Fine-tuning 학습 진행 (모든 모델에 대해 수행)
history_fine_list = []
base_epochs = 15
for fold, model in enumerate(models_list):
    print(f"Fine-tuning on Fold {fold+1}")

    # 이전 학습 이력에서 이어서 학습
    history_fine = model.fit(
        x_train, y_train,
        epochs=total_epochs,
        initial_epoch=base_epochs,  # 기존 학습된 에포크에서 이어감
        batch_size=256,
        validation_data=(x_test, y_test)
    )

    history_fine_list.append(history_fine)
# Out:
# Fine-tuning on Fold 1
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 54s 456ms/step - accuracy: 0.7692 - loss: 0.8001 - val_accuracy: 0.8412 - val_loss: 0.5767
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9064 - loss: 0.3927 - val_accuracy: 0.8524 - val_loss: 0.5452
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9483 - loss: 0.2970 - val_accuracy: 0.8541 - val_loss: 0.5365
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9685 - loss: 0.2310 - val_accuracy: 0.8557 - val_loss: 0.5312
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9857 - loss: 0.1896 - val_accuracy: 0.8520 - val_loss: 0.5364
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9942 - loss: 0.1634 - val_accuracy: 0.8533 - val_loss: 0.5441
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9861 - loss: 0.1702 - val_accuracy: 0.8498 - val_loss: 0.5505
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9960 - loss: 0.1400 - val_accuracy: 0.8544 - val_loss: 0.5391
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9993 - loss: 0.1216 - val_accuracy: 0.8459 - val_loss: 0.5626
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9978 - loss: 0.1202 - val_accuracy: 0.8414 - val_loss: 0.5825
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9988 - loss: 0.1090 - val_accuracy: 0.8405 - val_loss: 0.6017
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9923 - loss: 0.1254 - val_accuracy: 0.8414 - val_loss: 0.5734
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9984 - loss: 0.1041 - val_accuracy: 0.8450 - val_loss: 0.5576
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9997 - loss: 0.0929 - val_accuracy: 0.8412 - val_loss: 0.5650
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9994 - loss: 0.0887 - val_accuracy: 0.8482 - val_loss: 0.5445
# Fine-tuning on Fold 2
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 37s 362ms/step - accuracy: 0.7799 - loss: 0.7569 - val_accuracy: 0.8349 - val_loss: 0.5702
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9143 - loss: 0.3655 - val_accuracy: 0.8308 - val_loss: 0.5675
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9435 - loss: 0.2857 - val_accuracy: 0.8241 - val_loss: 0.6122
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9684 - loss: 0.2227 - val_accuracy: 0.8418 - val_loss: 0.5521
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9839 - loss: 0.1715 - val_accuracy: 0.8393 - val_loss: 0.5710
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9896 - loss: 0.1561 - val_accuracy: 0.8489 - val_loss: 0.5488
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9890 - loss: 0.1475 - val_accuracy: 0.8134 - val_loss: 0.6972
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9940 - loss: 0.1265 - val_accuracy: 0.8230 - val_loss: 0.6468
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9909 - loss: 0.1343 - val_accuracy: 0.8487 - val_loss: 0.5803
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9947 - loss: 0.1148 - val_accuracy: 0.8465 - val_loss: 0.5867
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9966 - loss: 0.1083 - val_accuracy: 0.8503 - val_loss: 0.5578
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9958 - loss: 0.1083 - val_accuracy: 0.8427 - val_loss: 0.5817
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9996 - loss: 0.0920 - val_accuracy: 0.8560 - val_loss: 0.5356
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9979 - loss: 0.0889 - val_accuracy: 0.8523 - val_loss: 0.5475
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9963 - loss: 0.0948 - val_accuracy: 0.8529 - val_loss: 0.5536
# Fine-tuning on Fold 3
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 35s 358ms/step - accuracy: 0.7819 - loss: 0.7482 - val_accuracy: 0.8500 - val_loss: 0.5446
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9064 - loss: 0.3825 - val_accuracy: 0.8477 - val_loss: 0.5388
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9442 - loss: 0.2831 - val_accuracy: 0.8322 - val_loss: 0.5738
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9659 - loss: 0.2266 - val_accuracy: 0.8428 - val_loss: 0.5482
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9790 - loss: 0.1874 - val_accuracy: 0.8455 - val_loss: 0.5464
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9899 - loss: 0.1581 - val_accuracy: 0.8418 - val_loss: 0.5579
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9902 - loss: 0.1464 - val_accuracy: 0.8377 - val_loss: 0.5813
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9904 - loss: 0.1381 - val_accuracy: 0.8314 - val_loss: 0.5847
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9953 - loss: 0.1234 - val_accuracy: 0.8363 - val_loss: 0.5711
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9992 - loss: 0.1066 - val_accuracy: 0.8365 - val_loss: 0.5637
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9981 - loss: 0.1022 - val_accuracy: 0.8423 - val_loss: 0.5550
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9975 - loss: 0.1023 - val_accuracy: 0.8336 - val_loss: 0.5883
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9997 - loss: 0.0900 - val_accuracy: 0.8399 - val_loss: 0.5621
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9996 - loss: 0.0845 - val_accuracy: 0.8397 - val_loss: 0.5612
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9983 - loss: 0.0834 - val_accuracy: 0.8457 - val_loss: 0.5479
# Fine-tuning on Fold 4
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 360ms/step - accuracy: 0.7862 - loss: 0.7433 - val_accuracy: 0.8530 - val_loss: 0.5212
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9083 - loss: 0.3714 - val_accuracy: 0.8569 - val_loss: 0.5077
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9431 - loss: 0.2840 - val_accuracy: 0.8491 - val_loss: 0.5301
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9679 - loss: 0.2193 - val_accuracy: 0.8467 - val_loss: 0.5339
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9821 - loss: 0.1831 - val_accuracy: 0.8471 - val_loss: 0.5352
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9845 - loss: 0.1593 - val_accuracy: 0.8448 - val_loss: 0.5458
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9854 - loss: 0.1571 - val_accuracy: 0.8364 - val_loss: 0.5653
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9936 - loss: 0.1267 - val_accuracy: 0.8407 - val_loss: 0.5721
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9926 - loss: 0.1244 - val_accuracy: 0.8416 - val_loss: 0.5618
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9983 - loss: 0.1061 - val_accuracy: 0.8460 - val_loss: 0.5581
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9986 - loss: 0.0993 - val_accuracy: 0.8414 - val_loss: 0.5774
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9963 - loss: 0.1001 - val_accuracy: 0.8377 - val_loss: 0.6007
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9943 - loss: 0.1008 - val_accuracy: 0.8418 - val_loss: 0.5979
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9972 - loss: 0.0932 - val_accuracy: 0.8357 - val_loss: 0.6271
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9995 - loss: 0.0813 - val_accuracy: 0.8443 - val_loss: 0.5729
# Fine-tuning on Fold 5
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 36s 366ms/step - accuracy: 0.7853 - loss: 0.7463 - val_accuracy: 0.8473 - val_loss: 0.5396
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9103 - loss: 0.3702 - val_accuracy: 0.8549 - val_loss: 0.5172
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9473 - loss: 0.2748 - val_accuracy: 0.8522 - val_loss: 0.5268
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9687 - loss: 0.2196 - val_accuracy: 0.8279 - val_loss: 0.6110
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9853 - loss: 0.1780 - val_accuracy: 0.8435 - val_loss: 0.5683
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9896 - loss: 0.1530 - val_accuracy: 0.8365 - val_loss: 0.5953
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9874 - loss: 0.1544 - val_accuracy: 0.8414 - val_loss: 0.5782
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9934 - loss: 0.1302 - val_accuracy: 0.8345 - val_loss: 0.6229
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9976 - loss: 0.1142 - val_accuracy: 0.8471 - val_loss: 0.5645
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9941 - loss: 0.1165 - val_accuracy: 0.8446 - val_loss: 0.5673
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9977 - loss: 0.1013 - val_accuracy: 0.8396 - val_loss: 0.5837
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9951 - loss: 0.1073 - val_accuracy: 0.8486 - val_loss: 0.5510
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9950 - loss: 0.1030 - val_accuracy: 0.8562 - val_loss: 0.5361
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9990 - loss: 0.0871 - val_accuracy: 0.8553 - val_loss: 0.5339
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 0.0796 - val_accuracy: 0.8488 - val_loss: 0.5628

# %% [markdown]
# # Step 8: 앙상블을 적용한 최종 평가

# %%
# Fine-Tuned 모델들의 예측값 저장
predictions_fine = np.array([model.predict(x_test) for model in models_list])

# 8-1. 소프트보팅 (Soft Voting) - Fine-Tuned 모델
final_pred_soft_fine = np.mean(predictions_fine, axis=0)
final_classes_soft_fine = np.argmax(final_pred_soft_fine, axis=1)

# 8-2. 하드보팅 (Hard Voting) - Fine-Tuned 모델
final_classes_hard_fine = mode([np.argmax(pred, axis=1) for pred in predictions_fine], axis=0)[0].flatten()

# 8-3. 가중치 앙상블 (Weighted Ensemble) - Fine-Tuned 모델
weights = [0.2, 0.3, 0.2, 0.1, 0.2]  # (예시) 가장 성능이 좋은 모델에 높은 가중치 부여
final_pred_weighted_fine = sum(weights[i] * predictions_fine[i] for i in range(len(models_list)))
final_classes_weighted_fine = np.argmax(final_pred_weighted_fine, axis=1)

# Fine-Tuning 후 앙상블 모델 평가
test_acc_soft_fine = np.mean(final_classes_soft_fine == y_test)
test_acc_hard_fine = np.mean(final_classes_hard_fine == y_test)
test_acc_weighted_fine = np.mean(final_classes_weighted_fine == y_test)

print(f"Fine-Tuned Soft Voting Accuracy: {test_acc_soft_fine:.4f}")
print(f"Fine-Tuned Hard Voting Accuracy: {test_acc_hard_fine:.4f}")
print(f"Fine-Tuned Weighted Ensemble Accuracy: {test_acc_weighted_fine:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step
# Fine-Tuned Soft Voting Accuracy: 0.8719
# Fine-Tuned Hard Voting Accuracy: 0.8684
# Fine-Tuned Weighted Ensemble Accuracy: 0.8730

# %% [markdown]
# # Step 9: 학습 결과 시각화 (Fine-Tuning 후 앙상블 반영)

# %%
import matplotlib.pyplot as plt

# 시각화 함수 정의 (Fine-Tuning 후 앙상블 성능 반영)
def plot_history(history_list, history_fine_list=None):
    plt.figure(figsize=(12, 6))

    for fold, history in enumerate(history_list):
        acc = history.history['accuracy']
        val_acc = history.history['val_accuracy']
        loss = history.history['loss']
        val_loss = history.history['val_loss']

        if history_fine_list:
            acc += history_fine_list[fold].history['accuracy']
            val_acc += history_fine_list[fold].history['val_accuracy']
            loss += history_fine_list[fold].history['loss']
            val_loss += history_fine_list[fold].history['val_loss']

        plt.subplot(1, 2, 1)
        plt.plot(acc, label=f'Training Fold {fold+1}')
        plt.plot(val_acc, label=f'Validation Fold {fold+1}')
        plt.legend(loc='lower right')
        plt.title('Training and Validation Accuracy')

        plt.subplot(1, 2, 2)
        plt.plot(loss, label=f'Training Fold {fold+1}')
        plt.plot(val_loss, label=f'Validation Fold {fold+1}')
        plt.legend(loc='upper right')
        plt.title('Training and Validation Loss')

    plt.show()

# Fine-Tuning 후 시각화 실행
plot_history(history_fine_list, history_fine_list)
